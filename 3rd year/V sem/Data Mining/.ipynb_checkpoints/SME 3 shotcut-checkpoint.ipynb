# %%
pip install dtale
# Out:
# ...
#   Using cached dtale-2.9.0-py2.py3-none-any.whl (12.8 MB)
# ...
#   Using cached Flask_Compress-1.13-py3-none-any.whl (7.9 kB)
# ...
#   Using cached dash-2.7.0-py3-none-any.whl (9.9 MB)
# ...
#   Using cached missingno-0.4.2-py3-none-any.whl (9.7 kB)
# ...
#   Using cached matplotlib-3.6.0-cp38-cp38-win_amd64.whl (7.2 MB)
# ...
#   Using cached dash_daq-0.5.0-py3-none-any.whl
# ...
#   Using cached dash_bootstrap_components-1.2.1-py3-none-any.whl (216 kB)
# ...
#   Using cached flask_ngrok-0.0.25-py3-none-any.whl (3.1 kB)
# ...
# Note: you may need to restart the kernel to use updated packages.
# WARNING: Ignoring invalid distribution -atplotlib (c:\users\naman\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -atplotlib (c:\users\naman\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -atplotlib (c:\users\naman\anaconda3\lib\site-packages)
# ...

# %%
import dtale
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-5-33560840fdc5> in <module>
# ----> 1 import dtale
#
# ModuleNotFoundError: No module named 'dtale'
