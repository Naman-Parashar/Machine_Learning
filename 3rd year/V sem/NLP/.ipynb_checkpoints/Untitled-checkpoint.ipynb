# %%
pip install spacy
# Out:
# Requirement already satisfied: spacy in c:\users\naman\anaconda3\lib\site-packages (3.4.2)
# Requirement already satisfied: spacy-legacy<3.1.0,>=3.0.10 in c:\users\naman\anaconda3\lib\site-packages (from spacy) (3.0.10)
# Requirement already satisfied: setuptools in c:\users\naman\anaconda3\lib\site-packages (from spacy) (65.5.0)
# Requirement already satisfied: jinja2 in c:\users\naman\anaconda3\lib\site-packages (from spacy) (2.11.3)
# Requirement already satisfied: numpy>=1.15.0 in c:\users\naman\anaconda3\lib\site-packages (from spacy) (1.20.1)
# Requirement already satisfied: catalogue<2.1.0,>=2.0.6 in c:\users\naman\anaconda3\lib\site-packages (from spacy) (2.0.8)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in c:\users\naman\anaconda3\lib\site-packages (from spacy) (2.25.1)
# Requirement already satisfied: packaging>=20.0 in c:\users\naman\anaconda3\lib\site-packages (from spacy) (20.9)
# Requirement already satisfied: spacy-loggers<2.0.0,>=1.0.0 in c:\users\naman\anaconda3\lib\site-packages (from spacy) (1.0.3)
# Requirement already satisfied: pathy>=0.3.5 in c:\users\naman\anaconda3\lib\site-packages (from spacy) (0.6.2)
# Requirement already satisfied: typer<0.5.0,>=0.3.0 in c:\users\naman\anaconda3\lib\site-packages (from spacy) (0.4.2)
# Requirement already satisfied: srsly<3.0.0,>=2.4.3 in c:\users\naman\anaconda3\lib\site-packages (from spacy) (2.4.5)
# Requirement already satisfied: langcodes<4.0.0,>=3.2.0 in c:\users\naman\anaconda3\lib\site-packages (from spacy) (3.3.0)
# Requirement already satisfied: wasabi<1.1.0,>=0.9.1 in c:\users\naman\anaconda3\lib\site-packages (from spacy) (0.10.1)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in c:\users\naman\anaconda3\lib\site-packages (from spacy) (3.0.8)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in c:\users\naman\anaconda3\lib\site-packages (from spacy) (1.0.9)
# Requirement already satisfied: thinc<8.2.0,>=8.1.0 in c:\users\naman\anaconda3\lib\site-packages (from spacy) (8.1.5)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in c:\users\naman\anaconda3\lib\site-packages (from spacy) (2.0.7)
# Requirement already satisfied: tqdm<5.0.0,>=4.38.0 in c:\users\naman\anaconda3\lib\site-packages (from spacy) (4.59.0)
# Requirement already satisfied: pydantic!=1.8,!=1.8.1,<1.11.0,>=1.7.4 in c:\users\naman\anaconda3\lib\site-packages (from spacy) (1.10.2)
# Requirement already satisfied: pyparsing>=2.0.2 in c:\users\naman\anaconda3\lib\site-packages (from packaging>=20.0->spacy) (2.4.7)
# Requirement already satisfied: smart-open<6.0.0,>=5.2.1 in c:\users\naman\anaconda3\lib\site-packages (from pathy>=0.3.5->spacy) (5.2.1)
# Requirement already satisfied: typing-extensions>=4.1.0 in c:\users\naman\anaconda3\lib\site-packages (from pydantic!=1.8,!=1.8.1,<1.11.0,>=1.7.4->spacy) (4.4.0)
# Requirement already satisfied: idna<3,>=2.5 in c:\users\naman\anaconda3\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy) (2.10)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\naman\anaconda3\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy) (2020.12.5)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\naman\anaconda3\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy) (1.26.4)
# Requirement already satisfied: chardet<5,>=3.0.2 in c:\users\naman\anaconda3\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy) (4.0.0)
# Requirement already satisfied: blis<0.8.0,>=0.7.8 in c:\users\naman\anaconda3\lib\site-packages (from thinc<8.2.0,>=8.1.0->spacy) (0.7.9)
# Requirement already satisfied: confection<1.0.0,>=0.0.1 in c:\users\naman\anaconda3\lib\site-packages (from thinc<8.2.0,>=8.1.0->spacy) (0.0.3)
# Requirement already satisfied: click<9.0.0,>=7.1.1 in c:\users\naman\anaconda3\lib\site-packages (from typer<0.5.0,>=0.3.0->spacy) (7.1.2)
# Requirement already satisfied: MarkupSafe>=0.23 in c:\users\naman\anaconda3\lib\site-packages (from jinja2->spacy) (1.1.1)
# Note: you may need to restart the kernel to use updated packages.

# %%
import spacy

# %%
pip install https://github.com/explosion/spacy-models/releases/download/en_core_web_sm-2.2.0/en_core_web_sm-2.2.0.tar.gz
# Out:
# Collecting https://github.com/explosion/spacy-models/releases/download/en_core_web_sm-2.2.0/en_core_web_sm-2.2.0.tar.gz
#   Downloading https://github.com/explosion/spacy-models/releases/download/en_core_web_sm-2.2.0/en_core_web_sm-2.2.0.tar.gz (12.0 MB)
#      --------------------------------------- 12.0/12.0 MB 93.1 kB/s eta 0:00:00
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# Requirement already satisfied: spacy>=2.2.0 in c:\users\naman\anaconda3\lib\site-packages (from en-core-web-sm==2.2.0) (3.4.2)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in c:\users\naman\anaconda3\lib\site-packages (from spacy>=2.2.0->en-core-web-sm==2.2.0) (2.25.1)
# Requirement already satisfied: pydantic!=1.8,!=1.8.1,<1.11.0,>=1.7.4 in c:\users\naman\anaconda3\lib\site-packages (from spacy>=2.2.0->en-core-web-sm==2.2.0) (1.10.2)
# Requirement already satisfied: numpy>=1.15.0 in c:\users\naman\anaconda3\lib\site-packages (from spacy>=2.2.0->en-core-web-sm==2.2.0) (1.20.1)
# Requirement already satisfied: langcodes<4.0.0,>=3.2.0 in c:\users\naman\anaconda3\lib\site-packages (from spacy>=2.2.0->en-core-web-sm==2.2.0) (3.3.0)
# Requirement already satisfied: catalogue<2.1.0,>=2.0.6 in c:\users\naman\anaconda3\lib\site-packages (from spacy>=2.2.0->en-core-web-sm==2.2.0) (2.0.8)
# Requirement already satisfied: tqdm<5.0.0,>=4.38.0 in c:\users\naman\anaconda3\lib\site-packages (from spacy>=2.2.0->en-core-web-sm==2.2.0) (4.59.0)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in c:\users\naman\anaconda3\lib\site-packages (from spacy>=2.2.0->en-core-web-sm==2.2.0) (2.0.7)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in c:\users\naman\anaconda3\lib\site-packages (from spacy>=2.2.0->en-core-web-sm==2.2.0) (3.0.8)
# Requirement already satisfied: packaging>=20.0 in c:\users\naman\anaconda3\lib\site-packages (from spacy>=2.2.0->en-core-web-sm==2.2.0) (20.9)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in c:\users\naman\anaconda3\lib\site-packages (from spacy>=2.2.0->en-core-web-sm==2.2.0) (1.0.9)
# Requirement already satisfied: typer<0.5.0,>=0.3.0 in c:\users\naman\anaconda3\lib\site-packages (from spacy>=2.2.0->en-core-web-sm==2.2.0) (0.4.2)
# Requirement already satisfied: spacy-loggers<2.0.0,>=1.0.0 in c:\users\naman\anaconda3\lib\site-packages (from spacy>=2.2.0->en-core-web-sm==2.2.0) (1.0.3)
# Requirement already satisfied: wasabi<1.1.0,>=0.9.1 in c:\users\naman\anaconda3\lib\site-packages (from spacy>=2.2.0->en-core-web-sm==2.2.0) (0.10.1)
# Requirement already satisfied: srsly<3.0.0,>=2.4.3 in c:\users\naman\anaconda3\lib\site-packages (from spacy>=2.2.0->en-core-web-sm==2.2.0) (2.4.5)
# Requirement already satisfied: spacy-legacy<3.1.0,>=3.0.10 in c:\users\naman\anaconda3\lib\site-packages (from spacy>=2.2.0->en-core-web-sm==2.2.0) (3.0.10)
# Requirement already satisfied: thinc<8.2.0,>=8.1.0 in c:\users\naman\anaconda3\lib\site-packages (from spacy>=2.2.0->en-core-web-sm==2.2.0) (8.1.5)
# Requirement already satisfied: jinja2 in c:\users\naman\anaconda3\lib\site-packages (from spacy>=2.2.0->en-core-web-sm==2.2.0) (2.11.3)
# Requirement already satisfied: setuptools in c:\users\naman\anaconda3\lib\site-packages (from spacy>=2.2.0->en-core-web-sm==2.2.0) (65.5.0)
# Requirement already satisfied: pathy>=0.3.5 in c:\users\naman\anaconda3\lib\site-packages (from spacy>=2.2.0->en-core-web-sm==2.2.0) (0.6.2)
# Requirement already satisfied: pyparsing>=2.0.2 in c:\users\naman\anaconda3\lib\site-packages (from packaging>=20.0->spacy>=2.2.0->en-core-web-sm==2.2.0) (2.4.7)
# Requirement already satisfied: smart-open<6.0.0,>=5.2.1 in c:\users\naman\anaconda3\lib\site-packages (from pathy>=0.3.5->spacy>=2.2.0->en-core-web-sm==2.2.0) (5.2.1)
# Requirement already satisfied: typing-extensions>=4.1.0 in c:\users\naman\anaconda3\lib\site-packages (from pydantic!=1.8,!=1.8.1,<1.11.0,>=1.7.4->spacy>=2.2.0->en-core-web-sm==2.2.0) (4.4.0)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\naman\anaconda3\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy>=2.2.0->en-core-web-sm==2.2.0) (1.26.4)
# Requirement already satisfied: idna<3,>=2.5 in c:\users\naman\anaconda3\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy>=2.2.0->en-core-web-sm==2.2.0) (2.10)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\naman\anaconda3\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy>=2.2.0->en-core-web-sm==2.2.0) (2020.12.5)
# Requirement already satisfied: chardet<5,>=3.0.2 in c:\users\naman\anaconda3\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy>=2.2.0->en-core-web-sm==2.2.0) (4.0.0)
# Requirement already satisfied: blis<0.8.0,>=0.7.8 in c:\users\naman\anaconda3\lib\site-packages (from thinc<8.2.0,>=8.1.0->spacy>=2.2.0->en-core-web-sm==2.2.0) (0.7.9)
# Requirement already satisfied: confection<1.0.0,>=0.0.1 in c:\users\naman\anaconda3\lib\site-packages (from thinc<8.2.0,>=8.1.0->spacy>=2.2.0->en-core-web-sm==2.2.0) (0.0.3)
# Requirement already satisfied: click<9.0.0,>=7.1.1 in c:\users\naman\anaconda3\lib\site-packages (from typer<0.5.0,>=0.3.0->spacy>=2.2.0->en-core-web-sm==2.2.0) (7.1.2)
# Requirement already satisfied: MarkupSafe>=0.23 in c:\users\naman\anaconda3\lib\site-packages (from jinja2->spacy>=2.2.0->en-core-web-sm==2.2.0) (1.1.1)
# Building wheels for collected packages: en-core-web-sm
#   Building wheel for en-core-web-sm (setup.py): started
#   Building wheel for en-core-web-sm (setup.py): finished with status 'done'
#   Created wheel for en-core-web-sm: filename=en_core_web_sm-2.2.0-py3-none-any.whl size=12019105 sha256=46e86c61f9696335092451764f0b8a8a34e45f0e262552e076eb21b5e1511a27
#   Stored in directory: c:\users\naman\appdata\local\pip\cache\wheels\fc\31\e9\092e6f05b2817c9cb45804a3d1bf2b9bf6575742c01819337c
# Successfully built en-core-web-sm
# Installing collected packages: en-core-web-sm
# Successfully installed en-core-web-sm-2.2.0
# Note: you may need to restart the kernel to use updated packages.

# %%
import en_core_web_sm

# %%
nlp = en_core_web_sm.load()
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# <ipython-input-13-e3796228f4af> in <module>
# ----> 1 nlp = en_core_web_sm.load()
#
# ~\anaconda3\lib\site-packages\en_core_web_sm\__init__.py in load(**overrides)
#      10
#      11 def load(**overrides):
# ---> 12     return load_model_from_init_py(__file__, **overrides)
#
# ~\anaconda3\lib\site-packages\spacy\util.py in load_model_from_init_py(init_file, vocab, disable, enable, exclude, config)
#     647     if not model_path.exists():
#     648         raise IOError(Errors.E052.format(path=data_path))
# --> 649     return load_model_from_path(
#     650         data_path,
#     651         vocab=vocab,
#
# ~\anaconda3\lib\site-packages\spacy\util.py in load_model_from_path(model_path, meta, vocab, disable, enable, exclude, config)
#     503     config_path = model_path / "config.cfg"
#     504     overrides = dict_to_dot(config)
# --> 505     config = load_config(config_path, overrides=overrides)
#     506     nlp = load_model_from_config(
#     507         config,
#
# ~\anaconda3\lib\site-packages\spacy\util.py in load_config(path, overrides, interpolate)
#     679     else:
#     680         if not config_path or not config_path.is_file():
# --> 681             raise IOError(Errors.E053.format(path=config_path, name="config file"))
#     682         return config.from_disk(
#     683             config_path, overrides=overrides, interpolate=interpolate
#
# OSError: [E053] Could not read config file from C:\Users\naman\anaconda3\lib\site-packages\en_core_web_sm\en_core_web_sm-2.2.0\config.cfg
