# %%
import collections
import numpy as np
import pandas as pd

# %%
pip install Py-Dictionary
# Out:
# Requirement already satisfied: Py-Dictionary in c:\users\naman\anaconda3\lib\site-packages (4.1.4)
# Requirement already satisfied: lxml in c:\users\naman\anaconda3\lib\site-packages (from Py-Dictionary) (4.6.3)
# Requirement already satisfied: requests in c:\users\naman\anaconda3\lib\site-packages (from Py-Dictionary) (2.25.1)
# Requirement already satisfied: string-color in c:\users\naman\anaconda3\lib\site-packages (from Py-Dictionary) (1.2.3)
# Requirement already satisfied: beautifulsoup4 in c:\users\naman\anaconda3\lib\site-packages (from Py-Dictionary) (4.9.3)
# Requirement already satisfied: soupsieve>1.2 in c:\users\naman\anaconda3\lib\site-packages (from beautifulsoup4->Py-Dictionary) (2.2.1)
# Requirement already satisfied: chardet<5,>=3.0.2 in c:\users\naman\anaconda3\lib\site-packages (from requests->Py-Dictionary) (4.0.0)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\naman\anaconda3\lib\site-packages (from requests->Py-Dictionary) (1.26.4)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\naman\anaconda3\lib\site-packages (from requests->Py-Dictionary) (2020.12.5)
# Requirement already satisfied: idna<3,>=2.5 in c:\users\naman\anaconda3\lib\site-packages (from requests->Py-Dictionary) (2.10)
# Requirement already satisfied: colorama in c:\users\naman\anaconda3\lib\site-packages (from string-color->Py-Dictionary) (0.4.4)
# Requirement already satisfied: columnar>=1.3.1 in c:\users\naman\anaconda3\lib\site-packages (from string-color->Py-Dictionary) (1.4.1)
# Requirement already satisfied: setuptools in c:\users\naman\anaconda3\lib\site-packages (from string-color->Py-Dictionary) (65.5.0)
# Requirement already satisfied: toolz in c:\users\naman\anaconda3\lib\site-packages (from columnar>=1.3.1->string-color->Py-Dictionary) (0.11.1)
# Requirement already satisfied: wcwidth in c:\users\naman\anaconda3\lib\site-packages (from columnar>=1.3.1->string-color->Py-Dictionary) (0.2.5)
# Note: you may need to restart the kernel to use updated packages.
# WARNING: Ignoring invalid distribution -atplotlib (c:\users\naman\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -atplotlib (c:\users\naman\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -atplotlib (c:\users\naman\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -atplotlib (c:\users\naman\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -atplotlib (c:\users\naman\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -atplotlib (c:\users\naman\anaconda3\lib\site-packages)

# %%
from pydictionary import Dictionary

# %%
dict = Dictionary("Apple")

# %%
meanings_list = dict.meanings()
meanings_list
# Out:
# No meaning of the word 'Apple' was found on dictionary.com
# []

# %%
synonyms_list = dict.synonyms()
antonyms_list = dict.antonyms()

# %%
synonyms_list
# Out:
# ['olive', 'aquamarine', 'beryl', 'chartreuse', 'fir']

# %%
antonyms_list
# Out:
# ['green']
