# %%
def equ(x1,x2,y1,y2):
  m=(y2-y1)/(x2-x1)
  c=y1-(m*x1)
  return (m,c)

# %%
m,c = equ(3,9,5,10)

# %%
print("Y=",'{:.2f}'.format(m),"x + ",c)
# Out:
# Y= 0.83 x +  2.5

# %%
import matplotlib.pyplot as plt
plt.plot([3,5],[9,10])

# %%
plt.plot([171,151,124,134,156],[80,60,45,50,65])
